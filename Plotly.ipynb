# %% [markdown]
# <a href="https://colab.research.google.com/github/127-0-0-vvk/Bird-Window-Collision-Death-Visualization/blob/main/Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly
import pandas as pd
import numpy as np
import cufflinks as cf
import matplotlib.pyplot as plt

# %%
# !pip install -U kaleido

# %%
import plotly.express as px
# This dataframe has 244 lines, but 4 distinct values for `day`
dfb = pd.read_csv("bird-window-collision-death.csv")
fig = px.pie(dfb, values='Deaths', names='Bldg #', color='Side', hole=0.3)
fig.update_traces(textinfo="label+percent", insidetextfont=dict(color="white"))
fig.update_layout(legend={"itemclick":False})
fig.show()


fig.write_image('fig.png', engine='kaleido')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px


fig = px.bar(dfb, x="MONTH", y="YEAR", color="MONTH", title="Deaths in Bar Graph")
fig.update_layout(legend={"itemclick":False})
fig.show()
fig.write_image('bar.png', engine='kaleido')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install dash

# %%
fig = px.scatter_matrix(dfb, dimensions=["Side", "SpeciesCode", "Deaths", "Bldg #"], color="YEAR")
fig.show()
fig.write_image('scatter.png', engine='kaleido')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
